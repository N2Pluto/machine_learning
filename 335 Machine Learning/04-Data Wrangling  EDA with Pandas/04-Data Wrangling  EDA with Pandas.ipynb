# %% [markdown]
# # CODING TASK #1. IMPORT DATASET AND PERFORM BASIC STATISTICAL DATA ANALYSIS

# %%
# Import Pandas Library
import pandas as pd

# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/335 Machine Learning/04-Data Wrangling  EDA with Pandas/"
# Out:
# /content/drive/MyDrive/Colab Notebooks/335 Machine Learning/04-Data Wrangling  EDA with Pandas

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('04-2-Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %%
# Let's obtain the datatype
type(hr_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-28f843a437ab> in <cell line: 2>()
#       1 # Let's obtain the datatype
# ----> 2 type(hr_df)
#
# NameError: name 'hr_df' is not defined

# %%
# you can view the first couple of rows using .head()
hr_df.head(6)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
# 5   32         3068.0        No  Travel_Frequently       1005
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# 5  Research & Development                 2          2  Life Sciences
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
# 3              1  ...                         3             80
# 4              1  ...                         4             80
# 5              1  ...                         3             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
# 3                0                  8                      3                3
# 4                1                  6                      3                3
# 5                0                  8                      2                2
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
# 3              8                   7                       3
# 4              2                   2                       2
# 5              7                   7                       3
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
# 5                     6
#
# [6 rows x 35 columns]

# %%
# you can view the last couple of rows using .tail()
hr_df.tail(4)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [4 rows x 35 columns]

# %%
# Calculate the average values for employee_df dataframe
hr_df.mean()
# Out:
# <ipython-input-9-859ebac24a6a>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hr_df.mean()
# Age                            36.923810
# MonthlyIncome                6505.155419
# DailyRate                     802.485714
# DistanceFromHome                9.192517
# Education                       2.912925
# EmployeeCount                   1.000000
# EmployeeNumber               1025.556161
# EnvironmentSatisfaction         2.721769
# HourlyRate                     65.891156
# JobInvolvement                  2.729932
# JobLevel                        2.063946
# JobSatisfaction                 2.728571
# MonthlyRate                 14310.966621
# NumCompaniesWorked              2.693197
# PercentSalaryHike              15.206263
# PerformanceRating               3.153165
# RelationshipSatisfaction        2.712245
# StandardHours                  80.000000
# StockOptionLevel                0.793878
# TotalWorkingYears              11.279592
# TrainingTimesLastYear           2.799320
# WorkLifeBalance                 2.761224
# YearsAtCompany                  7.008163
# YearsInCurrentRole              4.229252
# YearsSinceLastPromotion         2.187755
# YearsWithCurrManager            4.123129
# dtype: float64

# %%
# 35 features in total
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
#  13  HourlyRate                1470 non-null   int64
#  14  JobInvolvement            1470 non-null   int64
#  15  JobLevel                  1470 non-null   int64
#  16  JobRole                   1469 non-null   object
#  17  JobSatisfaction           1470 non-null   int64
#  18  MaritalStatus             1469 non-null   object
#  19  MonthlyRate               1468 non-null   float64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1469 non-null   float64
#  24  PerformanceRating         1469 non-null   float64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(5), int64(21), object(9)
# memory usage: 402.1+ KB

# %%
# Obtain a Statistical Summary about the data
hr_df.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1469.000000              1470.000000  1470.000000
# mean             1.0     1025.556161                 2.721769    65.891156
# std              0.0      601.646166                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      492.000000                 2.000000    48.000000
# 50%              1.0     1022.000000                 3.000000    66.000000
# 75%              1.0     1556.000000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean         2.729932  ...                  2.712245           80.0
# std          0.711561  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%          2.000000  ...                  2.000000           80.0
# 50%          3.000000  ...                  3.000000           80.0
# 75%          3.000000  ...                  4.000000           80.0
# max          4.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 [OPTIONAL]:**
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %% [markdown]
# # CODING TASK #2. DEALING WITH MISSING DATA

# %%
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %%
# Let's locate rows that have Null values
# Notice Row index 6 has many missing values
hr_df.isnull()
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# Let's see the total number of missing elements per column
hr_df.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# Drop any row that contains a Null value
# Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463
hr_df.dropna(how = 'any', inplace = True)

# %%
# Notice that row 1 for example is no longer existing!
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# 5     Research & Development                 2          2  Life Sciences
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# 5                 1  ...                         3             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# 5                   0                  8                      2
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# 5                   2              7                   7
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# 5                          3                     6
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1463 rows x 35 columns]

# %%
# Let's check if we still have any missing values
hr_df.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# Let's explore an alternative (smarter) method to deal with missing values
# Let's read the raw data again using Pandas as follows
hr_df = pd.read_csv('04-2-Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %%
# Calculate the average monthly income
hr_df['MonthlyIncome'].mean()
# Out:
# 6505.155419222904

# %%
# You can use Fillna to fill a given column with a certain value
hr_df["MonthlyIncome"].fillna(hr_df['MonthlyIncome'].mean(), inplace = True)

# %%
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41    5993.000000       Yes      Travel_Rarely       1102
# 1      49    6505.155419        No  Travel_Frequently        279
# 2      37    2090.000000       Yes      Travel_Rarely       1373
# 3      33    2909.000000        No  Travel_Frequently       1392
# 4      27    3468.000000        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36    2571.000000        No  Travel_Frequently        884
# 1466   39    9991.000000        No      Travel_Rarely        613
# 1467   27    6142.000000        No      Travel_Rarely        155
# 1468   49    5390.000000        No  Travel_Frequently       1023
# 1469   34    4404.000000        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 [OPTIONAL]:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
# Let's read a CSV file using Pandas as follows
employee_df = pd.read_csv('04-2-Human_Resources.csv')
employee_df['MonthlyRate']
# Out:
# 0       19479.0
# 1       24907.0
# 2        2396.0
# 3       23159.0
# 4       16632.0
#          ...
# 1465    12290.0
# 1466    21457.0
# 1467     5174.0
# 1468    13243.0
# 1469    10228.0
# Name: MonthlyRate, Length: 1470, dtype: float64

# %%
# first, let's locate rows that have Null values
employee_df.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
# Calculate the average monthly income
employee_df['MonthlyRate'].median()
# Out:
# 14235.5

# %%
# You can use Fillna to fill a given column with a certain value
employee_df['MonthlyRate'].fillna(employee_df['MonthlyRate'].median(), inplace = True)

# %%
# first, let's locate rows that have Null values
employee_df.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
employee_df['MonthlyRate']
# Out:
# 0       19479.0
# 1       24907.0
# 2        2396.0
# 3       23159.0
# 4       16632.0
#          ...
# 1465    12290.0
# 1466    21457.0
# 1467     5174.0
# 1468    13243.0
# 1469    10228.0
# Name: MonthlyRate, Length: 1470, dtype: float64

# %% [markdown]
# # CODING TASK #3: PERFORM ONE-HOT ENCODING

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('04-2-Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %%
hr_df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
hr_df['BusinessTravel']
# Out:
# 0           Travel_Rarely
# 1       Travel_Frequently
# 2           Travel_Rarely
# 3       Travel_Frequently
# 4           Travel_Rarely
#               ...
# 1465    Travel_Frequently
# 1466        Travel_Rarely
# 1467        Travel_Rarely
# 1468    Travel_Frequently
# 1469        Travel_Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
BusinessTravel_Encoded = pd.get_dummies(hr_df['BusinessTravel'])
print(BusinessTravel_Encoded)
# Out:
#       Non-Travel  Travel_Frequently  Travel_Rarely
# 0              0                  0              1
# 1              0                  1              0
# 2              0                  0              1
# 3              0                  1              0
# 4              0                  0              1
# ...          ...                ...            ...
# 1465           0                  1              0
# 1466           0                  0              1
# 1467           0                  0              1
# 1468           0                  1              0
# 1469           0                  0              1
#
# [1470 rows x 3 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('04-2-Human_Resources.csv')
hr_df.dropna(how = 'any', inplace = True)

# %%
hr_df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
EducationField_Encoded = pd.get_dummies(hr_df['EducationField'])
EducationField_Encoded
# Out:
#       Human Resources  Life Sciences  Marketing  Medical  Other  \
# 0                   0              1          0        0      0
# 2                   0              0          0        0      1
# 3                   0              1          0        0      0
# 4                   0              0          0        1      0
# 5                   0              1          0        0      0
# ...               ...            ...        ...      ...    ...
# 1465                0              0          0        1      0
# 1466                0              0          0        1      0
# 1467                0              1          0        0      0
# 1468                0              0          0        1      0
# 1469                0              0          0        1      0
#
#       Technical Degree
# 0                    0
# 2                    0
# 3                    0
# 4                    0
# 5                    0
# ...                ...
# 1465                 0
# 1466                 0
# 1467                 0
# 1468                 0
# 1469                 0
#
# [1463 rows x 6 columns]

# %% [markdown]
# # CODING TASK #4: PERFORM SCALING (NORMALIZATION & STANDARDIZATION)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('04-2-Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %%
hr_df.describe().round(2)
# Out:
#            Age  MonthlyIncome  DailyRate  DistanceFromHome  Education  \
# count  1463.00        1463.00    1463.00           1463.00    1463.00
# mean      0.00        6514.97     802.11              9.18       2.92
# std       1.00        4713.52     403.46              8.11       1.02
# min      -2.08        1009.00     102.00              1.00       1.00
# 25%      -0.76        2918.50     465.00              2.00       2.00
# 50%      -0.10        4936.00     802.00              7.00       3.00
# 75%       0.67        8380.50    1157.00             14.00       4.00
# max       2.54       19999.00    1499.00             29.00       5.00
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# count         1463.0         1463.00                  1463.00     1463.00
# mean             1.0         1028.72                     2.72       65.86
# std              0.0          600.06                     1.09       20.33
# min              1.0            1.00                     1.00       30.00
# 25%              1.0          495.50                     2.00       48.00
# 50%              1.0         1025.00                     3.00       66.00
# 75%              1.0         1557.50                     4.00       83.50
# max              1.0         2068.00                     4.00      100.00
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count         1463.00  ...                   1463.00         1463.0
# mean             2.73  ...                      2.71           80.0
# std              0.71  ...                      1.08            0.0
# min              1.00  ...                      1.00           80.0
# 25%              2.00  ...                      2.00           80.0
# 50%              3.00  ...                      3.00           80.0
# 75%              3.00  ...                      4.00           80.0
# max              4.00  ...                      4.00           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count           1463.00            1463.00                1463.00
# mean               0.79              11.30                   2.80
# std                0.85               7.78                   1.29
# min                0.00               0.00                   0.00
# 25%                0.00               6.00                   2.00
# 50%                1.00              10.00                   3.00
# 75%                1.00              15.00                   3.00
# max                3.00              40.00                   6.00
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count          1463.00         1463.00             1463.00
# mean              2.76            7.02                4.23
# std               0.71            6.13                3.62
# min               1.00            0.00                0.00
# 25%               2.00            3.00                2.00
# 50%               3.00            5.00                3.00
# 75%               3.00            9.00                7.00
# max               4.00           40.00               18.00
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count                  1463.00               1463.00
# mean                      2.19                  4.13
# std                       3.23                  3.57
# min                       0.00                  0.00
# 25%                       0.00                  2.00
# 50%                       1.00                  3.00
# 75%                       3.00                  7.00
# max                      15.00                 17.00
#
# [8 rows x 26 columns]

# %%
hr_df['Age'].values
# Out:
# array([41, 37, 33, ..., 27, 49, 34])

# %%
# Normalization is conducted to make feature values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
hr_df['Age'] = scaler.fit_transform(hr_df['Age'].values.reshape(-1,1))  #reshape to column view

# %%
hr_df['Age']
# Out:
# 0       41
# 2       37
# 3       33
# 4       27
# 5       32
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1463, dtype: int64

# %%
hr_df.describe().round(2)
# Out:
#            Age  MonthlyIncome  DailyRate  DistanceFromHome  Education  \
# count  1463.00        1463.00    1463.00           1463.00    1463.00
# mean      0.45        6514.97     802.11              9.18       2.92
# std       0.22        4713.52     403.46              8.11       1.02
# min       0.00        1009.00     102.00              1.00       1.00
# 25%       0.29        2918.50     465.00              2.00       2.00
# 50%       0.43        4936.00     802.00              7.00       3.00
# 75%       0.60        8380.50    1157.00             14.00       4.00
# max       1.00       19999.00    1499.00             29.00       5.00
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# count         1463.0         1463.00                  1463.00     1463.00
# mean             1.0         1028.72                     2.72       65.86
# std              0.0          600.06                     1.09       20.33
# min              1.0            1.00                     1.00       30.00
# 25%              1.0          495.50                     2.00       48.00
# 50%              1.0         1025.00                     3.00       66.00
# 75%              1.0         1557.50                     4.00       83.50
# max              1.0         2068.00                     4.00      100.00
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count         1463.00  ...                   1463.00         1463.0
# mean             2.73  ...                      2.71           80.0
# std              0.71  ...                      1.08            0.0
# min              1.00  ...                      1.00           80.0
# 25%              2.00  ...                      2.00           80.0
# 50%              3.00  ...                      3.00           80.0
# 75%              3.00  ...                      4.00           80.0
# max              4.00  ...                      4.00           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count           1463.00            1463.00                1463.00
# mean               0.79              11.30                   2.80
# std                0.85               7.78                   1.29
# min                0.00               0.00                   0.00
# 25%                0.00               6.00                   2.00
# 50%                1.00              10.00                   3.00
# 75%                1.00              15.00                   3.00
# max                3.00              40.00                   6.00
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count          1463.00         1463.00             1463.00
# mean              2.76            7.02                4.23
# std               0.71            6.13                3.62
# min               1.00            0.00                0.00
# 25%               2.00            3.00                2.00
# 50%               3.00            5.00                3.00
# 75%               3.00            9.00                7.00
# max               4.00           40.00               18.00
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count                  1463.00               1463.00
# mean                      2.19                  4.13
# std                       3.23                  3.57
# min                       0.00                  0.00
# 25%                       0.00                  2.00
# 50%                       1.00                  3.00
# 75%                       3.00                  7.00
# max                      15.00                 17.00
#
# [8 rows x 26 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
hr_df['Age'] = scaler.fit_transform(hr_df['Age'].values.reshape(-1,1))

# %%
hr_df.describe().round(2)
# Out:
#            Age  MonthlyIncome  DailyRate  DistanceFromHome  Education  \
# count  1463.00        1463.00    1463.00           1463.00    1463.00
# mean      0.45        6514.97     802.11              9.18       2.92
# std       0.22        4713.52     403.46              8.11       1.02
# min       0.00        1009.00     102.00              1.00       1.00
# 25%       0.29        2918.50     465.00              2.00       2.00
# 50%       0.43        4936.00     802.00              7.00       3.00
# 75%       0.60        8380.50    1157.00             14.00       4.00
# max       1.00       19999.00    1499.00             29.00       5.00
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# count         1463.0         1463.00                  1463.00     1463.00
# mean             1.0         1028.72                     2.72       65.86
# std              0.0          600.06                     1.09       20.33
# min              1.0            1.00                     1.00       30.00
# 25%              1.0          495.50                     2.00       48.00
# 50%              1.0         1025.00                     3.00       66.00
# 75%              1.0         1557.50                     4.00       83.50
# max              1.0         2068.00                     4.00      100.00
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count         1463.00  ...                   1463.00         1463.0
# mean             2.73  ...                      2.71           80.0
# std              0.71  ...                      1.08            0.0
# min              1.00  ...                      1.00           80.0
# 25%              2.00  ...                      2.00           80.0
# 50%              3.00  ...                      3.00           80.0
# 75%              3.00  ...                      4.00           80.0
# max              4.00  ...                      4.00           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count           1463.00            1463.00                1463.00
# mean               0.79              11.30                   2.80
# std                0.85               7.78                   1.29
# min                0.00               0.00                   0.00
# 25%                0.00               6.00                   2.00
# 50%                1.00              10.00                   3.00
# 75%                1.00              15.00                   3.00
# max                3.00              40.00                   6.00
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count          1463.00         1463.00             1463.00
# mean              2.76            7.02                4.23
# std               0.71            6.13                3.62
# min               1.00            0.00                0.00
# 25%               2.00            3.00                2.00
# 50%               3.00            5.00                3.00
# 75%               3.00            9.00                7.00
# max               4.00           40.00               18.00
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count                  1463.00               1463.00
# mean                      2.19                  4.13
# std                       3.23                  3.57
# min                       0.00                  0.00
# 25%                       0.00                  2.00
# 50%                       1.00                  3.00
# 75%                       3.00                  7.00
# max                      15.00                 17.00
#
# [8 rows x 26 columns]

# %% [markdown]
# # CODING TASK #5. PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-26a979aa5185> in <cell line: 2>()
#       1 # Let's read a CSV file using Pandas as follows
# ----> 2 hr_df = pd.read_csv('Human_Resources.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Human_Resources.csv'

# %%
# Pick certain rows that satisfy a certain criteria
loyal_employees_df = hr_df[ (hr_df['YearsAtCompany'] >= 30) ]
loyal_employees_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e5f447ee5d90> in <cell line: 2>()
#       1 # Pick certain rows that satisfy a certain criteria
# ----> 2 loyal_employees_df = hr_df[ (hr_df['YearsAtCompany'] >= 30) ]
#       3 loyal_employees_df
#
# NameError: name 'hr_df' is not defined

# %%
# Pick certain rows that satisfy 2 or more critirea

mask_1 = hr_df['YearsAtCompany'] >= 30
mask_2 = hr_df['Department'] == 'Research & Development'

loyal_rnd_df = hr_df[mask_1 & mask_2 ]
loyal_rnd_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 126    58        10312.0       Yes      Travel_Rarely        147
# 190    52        19999.0        No      Travel_Rarely        699
# 270    55        19045.0        No      Travel_Rarely        452
# 473    49        19502.0        No      Travel_Rarely       1245
# 595    58        19246.0       Yes      Travel_Rarely        286
# 653    50        17924.0        No         Non-Travel        881
# 914    55        13577.0        No         Non-Travel        177
# 1086   50        14411.0        No  Travel_Frequently        333
# 1111   53        10169.0       Yes      Travel_Rarely        607
# 1138   50        11245.0        No  Travel_Frequently       1234
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 126   Research & Development                23          4           Medical
# 190   Research & Development                 1          4     Life Sciences
# 270   Research & Development                 1          3           Medical
# 473   Research & Development                18          4     Life Sciences
# 595   Research & Development                 2          4     Life Sciences
# 653   Research & Development                 2          4     Life Sciences
# 914   Research & Development                 8          1           Medical
# 1086  Research & Development                22          5           Medical
# 1111  Research & Development                 2          5  Technical Degree
# 1138  Research & Development                20          5           Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 126               1  ...                         4             80
# 190               1  ...                         1             80
# 270               1  ...                         3             80
# 473               1  ...                         3             80
# 595               1  ...                         4             80
# 653               1  ...                         4             80
# 914               1  ...                         4             80
# 1086              1  ...                         4             80
# 1111              1  ...                         2             80
# 1138              1  ...                         3             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 126                 1                 40                      3
# 190                 1                 34                      5
# 270                 0                 37                      2
# 473                 1                 31                      5
# 595                 0                 40                      2
# 653                 1                 31                      3
# 914                 1                 34                      3
# 1086                0                 32                      2
# 1111                1                 34                      4
# 1138                1                 32                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 126                 2             40                  10
# 190                 3             33                  18
# 270                 3             36                  10
# 473                 3             31                   9
# 595                 3             31                  15
# 653                 3             31                   6
# 914                 3             33                   9
# 1086                3             32                   6
# 1111                3             33                   7
# 1138                3             30                   8
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 126                       15                     6
# 190                       11                     9
# 270                        4                    13
# 473                        0                     9
# 595                       13                     8
# 653                       14                     7
# 914                       15                     0
# 1086                      13                     9
# 1111                       1                     9
# 1138                      12                    13
#
# [10 rows x 35 columns]

# %%
# values that fall between a given range
hr_df[hr_df["DailyRate"].between(800, 850)]
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 10     35         2426.0        No      Travel_Rarely        809
# 34     24         2293.0       Yes      Travel_Rarely        813
# 65     55        14756.0        No      Travel_Rarely        836
# 100    37         2073.0       Yes      Travel_Rarely        807
# 101    32         2956.0        No      Travel_Rarely        827
# 125    26         2368.0        No      Travel_Rarely        841
# 131    50         9208.0        No  Travel_Frequently        809
# 133    41         8189.0        No      Travel_Rarely        802
# 211    30         8474.0        No         Non-Travel        829
# 232    59         2267.0        No      Travel_Rarely        818
# 234    33         2436.0       Yes      Travel_Rarely        813
# 246    33         2911.0        No      Travel_Rarely        832
# 258    51         2723.0        No      Travel_Rarely        833
# 301    18         1200.0        No      Travel_Rarely        812
# 307    38        12061.0        No      Travel_Rarely        849
# 348    42        15992.0        No      Travel_Rarely        810
# 358    36         6653.0        No         Non-Travel        845
# 392    54        19406.0        No      Travel_Rarely        821
# 450    31         6582.0        No      Travel_Rarely        828
# 476    24         2127.0        No      Travel_Rarely        823
# 517    25         4851.0        No      Travel_Rarely        810
# 519    29         2720.0        No  Travel_Frequently        806
# 520    48         8120.0        No      Travel_Rarely        817
# 529    38         7625.0        No      Travel_Rarely        827
# 552    56        11103.0        No      Travel_Rarely        832
# 553    40         2342.0        No      Travel_Rarely        804
# 576    27         4342.0        No  Travel_Frequently        829
# 589    29         2319.0       Yes      Travel_Rarely        805
# 613    34         3737.0        No      Travel_Rarely        829
# 659    28         4908.0        No      Travel_Rarely        821
# 696    45         4447.0        No         Non-Travel        805
# 715    33         5488.0        No  Travel_Frequently        827
# 716    41        19419.0        No  Travel_Frequently        840
# 740    35         3917.0        No      Travel_Rarely        802
# 742    50         2380.0        No      Travel_Rarely        804
# 792    33         4508.0       Yes  Travel_Frequently        827
# 846    35        10274.0        No      Travel_Rarely        819
# 856    20         3033.0        No      Travel_Rarely        805
# 932    29         3339.0       Yes      Travel_Rarely        806
# 938    58         2372.0        No      Travel_Rarely        848
# 973    35         5363.0        No      Travel_Rarely        817
# 1055   34        17007.0        No  Travel_Frequently        829
# 1061   24         2033.0        No         Non-Travel        830
# 1101   32         5878.0        No      Travel_Rarely        824
# 1150   35         5208.0        No      Travel_Rarely        819
# 1177   50        13269.0        No      Travel_Rarely        813
# 1195   49        15379.0        No      Travel_Rarely        809
# 1261   38         5811.0        No      Travel_Rarely        833
# 1262   43         2437.0       Yes  Travel_Frequently        807
# 1285   46         7991.0        No         Non-Travel        849
# 1300   34         6799.0        No      Travel_Rarely        810
# 1330   43        19392.0        No      Travel_Rarely        823
# 1335   39         3902.0        No      Travel_Rarely        835
# 1336   55         2662.0        No      Travel_Rarely        836
# 1431   32        10422.0        No      Travel_Rarely        801
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 10    Research & Development                16          3           Medical
# 34    Research & Development                 1          3           Medical
# 65    Research & Development                 8          3           Medical
# 100          Human Resources                 6          4   Human Resources
# 101   Research & Development                 1          1     Life Sciences
# 125   Research & Development                 6          3             Other
# 131                    Sales                12          3         Marketing
# 133                    Sales                 9          1     Life Sciences
# 211   Research & Development                 1          1     Life Sciences
# 232          Human Resources                 6          2           Medical
# 234   Research & Development                14          3           Medical
# 246   Research & Development                 5          4     Life Sciences
# 258   Research & Development                 1          3     Life Sciences
# 301                    Sales                10          3           Medical
# 307   Research & Development                25          2     Life Sciences
# 348   Research & Development                23          5     Life Sciences
# 358                    Sales                 1          5           Medical
# 392   Research & Development                 5          2           Medical
# 450                    Sales                 2          1     Life Sciences
# 476   Research & Development                17          2             Other
# 517                    Sales                 8          3     Life Sciences
# 519   Research & Development                 1          4     Life Sciences
# 520                    Sales                 2          1         Marketing
# 529   Research & Development                 1          4     Life Sciences
# 552   Research & Development                 9          3           Medical
# 553   Research & Development                 2          1           Medical
# 576                    Sales                 8          1         Marketing
# 589   Research & Development                 1          2     Life Sciences
# 613          Human Resources                 3          2   Human Resources
# 659                    Sales                 5          4           Medical
# 696   Research & Development                 4          2     Life Sciences
# 715   Research & Development                 1          4             Other
# 716   Research & Development                 9          3           Medical
# 740   Research & Development                10          3             Other
# 742   Research & Development                 9          3     Life Sciences
# 792   Research & Development                29          4           Medical
# 846   Research & Development                 2          3     Life Sciences
# 856   Research & Development                 3          3     Life Sciences
# 932   Research & Development                 7          3  Technical Degree
# 938   Research & Development                23          4     Life Sciences
# 973   Research & Development                 1          3           Medical
# 1055  Research & Development                15          3           Medical
# 1061                   Sales                13          2     Life Sciences
# 1101  Research & Development                 5          2     Life Sciences
# 1150  Research & Development                18          5     Life Sciences
# 1177  Research & Development                17          5     Life Sciences
# 1195  Research & Development                 1          3     Life Sciences
# 1261  Research & Development                18          3           Medical
# 1262  Research & Development                17          3  Technical Degree
# 1285                   Sales                26          2     Life Sciences
# 1300                   Sales                 8          2  Technical Degree
# 1330  Research & Development                 6          3           Medical
# 1335  Research & Development                19          4             Other
# 1336  Research & Development                 2          4  Technical Degree
# 1431                   Sales                 1          4         Marketing
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 10                1  ...                         3             80
# 34                1  ...                         1             80
# 65                1  ...                         3             80
# 100               1  ...                         4             80
# 101               1  ...                         4             80
# 125               1  ...                         3             80
# 131               1  ...                         4             80
# 133               1  ...                         3             80
# 211               1  ...                         3             80
# 232               1  ...                         4             80
# 234               1  ...                         3             80
# 246               1  ...                         3             80
# 258               1  ...                         2             80
# 301               1  ...                         1             80
# 307               1  ...                         3             80
# 348               1  ...                         2             80
# 358               1  ...                         2             80
# 392               1  ...                         3             80
# 450               1  ...                         3             80
# 476               1  ...                         4             80
# 517               1  ...                         3             80
# 519               1  ...                         4             80
# 520               1  ...                         4             80
# 529               1  ...                         3             80
# 552               1  ...                         3             80
# 553               1  ...                         4             80
# 576               1  ...                         2             80
# 589               1  ...                         4             80
# 613               1  ...                         3             80
# 659               1  ...                         2             80
# 696               1  ...                         2             80
# 715               1  ...                         1             80
# 716               1  ...                         2             80
# 740               1  ...                         1             80
# 742               1  ...                         2             80
# 792               1  ...                         2             80
# 846               1  ...                         2             80
# 856               1  ...                         1             80
# 932               1  ...                         1             80
# 938               1  ...                         4             80
# 973               1  ...                         2             80
# 1055              1  ...                         4             80
# 1061              1  ...                         3             80
# 1101              1  ...                         1             80
# 1150              1  ...                         4             80
# 1177              1  ...                         3             80
# 1195              1  ...                         1             80
# 1261              1  ...                         3             80
# 1262              1  ...                         4             80
# 1285              1  ...                         3             80
# 1300              1  ...                         3             80
# 1330              1  ...                         4             80
# 1335              1  ...                         2             80
# 1336              1  ...                         2             80
# 1431              1  ...                         3             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 10                  1                  6                      5
# 34                  1                  6                      2
# 65                  3                 21                      2
# 100                 0                  7                      3
# 101                 0                  1                      2
# 125                 0                  5                      3
# 131                 0                 16                      3
# 133                 1                 12                      2
# 211                 0                 12                      2
# 232                 0                  7                      2
# 234                 1                  8                      2
# 246                 1                  2                      2
# 258                 0                  1                      0
# 301                 0                  0                      2
# 307                 1                 19                      2
# 348                 0                 16                      2
# 358                 0                  7                      6
# 392                 1                 24                      4
# 450                 0                 10                      2
# 476                 1                  1                      2
# 517                 1                  4                      4
# 519                 1                 10                      5
# 520                 0                 12                      3
# 529                 0                 10                      4
# 552                 0                 30                      1
# 553                 0                  5                      2
# 576                 1                  5                      3
# 589                 1                  1                      1
# 613                 1                  4                      1
# 659                 0                  4                      3
# 696                 0                  9                      5
# 715                 1                  6                      2
# 716                 1                 21                      2
# 740                 1                  3                      4
# 742                 0                  8                      5
# 792                 0                 14                      4
# 846                 1                 15                      2
# 856                 0                  2                      2
# 932                 2                 10                      2
# 938                 2                  2                      3
# 973                 1                 10                      0
# 1055                2                 16                      3
# 1061                1                  1                      2
# 1101                1                 12                      2
# 1150                0                 16                      2
# 1177                3                 19                      3
# 1195                0                 23                      2
# 1261                1                 15                      2
# 1262                1                  6                      4
# 1285                0                  6                      3
# 1300                2                 10                      5
# 1330                0                 21                      2
# 1335                3                  7                      2
# 1336                1                 19                      2
# 1431                2                 14                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 10                  3              5                   4
# 34                  2              2                   0
# 65                  3              5                   0
# 100                 3              3                   2
# 101                 3              1                   0
# 125                 2              5                   4
# 131                 3              2                   2
# 133                 3              9                   7
# 211                 3             11                   8
# 232                 2              2                   2
# 234                 1              5                   4
# 246                 2              2                   2
# 258                 2              1                   0
# 301                 3              0                   0
# 307                 3             10                   8
# 348                 3              1                   0
# 358                 3              1                   0
# 392                 2              4                   2
# 450                 4              6                   5
# 476                 3              1                   0
# 517                 3              3                   2
# 519                 3             10                   7
# 520                 3              2                   2
# 529                 2              9                   7
# 552                 2             10                   7
# 553                 2              4                   2
# 576                 3              4                   2
# 589                 3              1                   0
# 613                 1              3                   2
# 659                 3              4                   2
# 696                 2              9                   7
# 715                 3              6                   5
# 716                 4             18                  16
# 740                 2              3                   2
# 742                 3              1                   0
# 792                 3             13                   7
# 846                 4              7                   7
# 856                 2              2                   2
# 932                 3              7                   7
# 938                 3              2                   2
# 973                 3              9                   7
# 1055                2             14                   8
# 1061                3              1                   0
# 1101                3              7                   1
# 1150                3             16                  15
# 1177                3             14                  11
# 1195                3              8                   7
# 1261                3              1                   0
# 1262                3              1                   0
# 1285                3              2                   2
# 1300                3             10                   8
# 1330                3             16                  12
# 1335                3              2                   2
# 1336                4              5                   2
# 1431                3             14                  10
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 10                         0                     3
# 34                         2                     0
# 65                         0                     2
# 100                        0                     2
# 101                        0                     0
# 125                        4                     3
# 131                        2                     1
# 133                        0                     7
# 211                        5                     8
# 232                        2                     2
# 234                        0                     4
# 246                        0                     2
# 258                        0                     0
# 301                        0                     0
# 307                        0                     1
# 348                        0                     0
# 358                        0                     0
# 392                        1                     2
# 450                        0                     5
# 476                        0                     0
# 517                        1                     2
# 519                        2                     8
# 520                        2                     2
# 529                        1                     8
# 552                        1                     1
# 553                        2                     3
# 576                        1                     1
# 589                        0                     0
# 613                        0                     2
# 659                        0                     2
# 696                        0                     8
# 715                        1                     2
# 716                        0                    11
# 740                        1                     2
# 742                        0                     0
# 792                        3                     8
# 846                        6                     4
# 856                        1                     2
# 932                        7                     7
# 938                        2                     2
# 973                        0                     0
# 1055                       6                     9
# 1061                       0                     0
# 1101                       2                     5
# 1150                       1                    10
# 1177                       1                    11
# 1195                       0                     0
# 1261                       1                     0
# 1262                       0                     0
# 1285                       2                     2
# 1300                       4                     8
# 1330                       6                    14
# 1335                       2                     2
# 1336                       0                     4
# 1431                       5                     7
#
# [55 rows x 35 columns]

# %%
hr_df[hr_df["DailyRate"].between(800, 850)].describe().round(2)
# Out:
#          Age  MonthlyIncome  DailyRate  DistanceFromHome  Education  \
# count  55.00          55.00      55.00             55.00      55.00
# mean   37.65        6579.96     821.00              8.60       2.89
# std    10.11        5068.57      13.46              7.62       1.10
# min    18.00        1200.00     801.00              1.00       1.00
# 25%    31.50        2549.50     809.00              2.00       2.00
# 50%    35.00        4851.00     821.00              6.00       3.00
# 75%    44.00        8331.50     829.50             13.50       4.00
# max    59.00       19419.00     849.00             29.00       5.00
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# count           55.0           55.00                    55.00       55.00
# mean             1.0          920.25                     2.55       66.75
# std              0.0          589.58                     1.05       19.84
# min              1.0           14.00                     1.00       33.00
# 25%              1.0          416.00                     2.00       49.00
# 50%              1.0          816.00                     3.00       64.00
# 75%              1.0         1427.00                     3.00       84.00
# max              1.0         2016.00                     4.00       98.00
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count           55.00  ...                     55.00           55.0
# mean             2.73  ...                      2.73           80.0
# std              0.73  ...                      1.01            0.0
# min              1.00  ...                      1.00           80.0
# 25%              2.00  ...                      2.00           80.0
# 50%              3.00  ...                      3.00           80.0
# 75%              3.00  ...                      3.50           80.0
# max              4.00  ...                      4.00           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count             55.00              55.00                  55.00
# mean               0.76              10.02                   2.64
# std                0.84               7.03                   1.25
# min                0.00               0.00                   0.00
# 25%                0.00               5.00                   2.00
# 50%                1.00               9.00                   2.00
# 75%                1.00              15.00                   3.00
# max                3.00              30.00                   6.00
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count            55.00           55.00               55.00
# mean              2.76            5.71                4.05
# std               0.64            4.71                3.98
# min               1.00            0.00                0.00
# 25%               2.00            2.00                1.50
# 50%               3.00            4.00                2.00
# 75%               3.00            9.00                7.00
# max               4.00           18.00               16.00
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count                    55.00                 55.00
# mean                      1.40                  3.44
# std                       1.88                  3.57
# min                       0.00                  0.00
# 25%                       0.00                  0.50
# 50%                       1.00                  2.00
# 75%                       2.00                  6.00
# max                       7.00                 14.00
#
# [8 rows x 26 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #5 [OPTIONAL]:**
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**
#
# **ให้สร้างตัวแปรใหม่ที่ชื่อ high_rate_df**

# %%
high_rate_df = hr_df[ (hr_df['DailyRate'] >= 1450) ]
high_rate_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 31     44         6465.0        No      Travel_Rarely       1459
# 52     44         5454.0        No      Travel_Rarely       1488
# 110    51         7484.0        No  Travel_Frequently       1456
# 117    36         9738.0        No  Travel_Frequently       1467
# 155    29         4319.0        No         Non-Travel       1496
# 164    27         2566.0        No         Non-Travel       1450
# 165    50        19926.0        No      Travel_Rarely       1452
# 172    36         2088.0        No  Travel_Frequently       1480
# 213    51        12490.0        No      Travel_Rarely       1469
# 266    31         5582.0        No      Travel_Rarely       1463
# 278    26         6397.0        No  Travel_Frequently       1479
# 302    28         5661.0        No      Travel_Rarely       1476
# 329    47        18300.0        No      Travel_Rarely       1482
# 373    27         3816.0        No      Travel_Rarely       1469
# 396    43         4522.0        No      Travel_Rarely       1473
# 408    52        16555.0        No      Travel_Rarely       1490
# 412    46         4810.0        No      Travel_Rarely       1485
# 416    38         1702.0        No  Travel_Frequently       1490
# 427    60        10266.0        No  Travel_Frequently       1499
# 441    42         2093.0        No  Travel_Frequently       1474
# 469    32         4707.0       Yes         Non-Travel       1474
# 471    38         9824.0        No      Travel_Rarely       1495
# 665    47         3294.0        No      Travel_Rarely       1454
# 678    48         2259.0        No      Travel_Rarely       1469
# 691    40         3617.0        No  Travel_Frequently       1469
# 706    40        13194.0       Yes         Non-Travel       1479
# 766    50        19237.0        No      Travel_Rarely       1464
# 785    40        10322.0        No      Travel_Rarely       1492
# 819    28         3201.0        No      Travel_Rarely       1451
# 842    28         2515.0       Yes      Travel_Rarely       1485
# 854    45         4477.0        No      Travel_Rarely       1457
# 869    46        19081.0        No      Travel_Rarely       1450
# 886    30         3579.0        No      Travel_Rarely       1465
# 944    28         6674.0        No         Non-Travel       1476
# 986    39         6120.0        No      Travel_Rarely       1498
# 992    39        10920.0        No         Non-Travel       1485
# 1001   37         3629.0        No      Travel_Rarely       1462
# 1006   49         4284.0       Yes  Travel_Frequently       1475
# 1025   24         4162.0        No      Travel_Rarely       1476
# 1044   49         6651.0        No      Travel_Rarely       1495
# 1046   44         3420.0        No      Travel_Rarely       1467
# 1054   49        10466.0        No      Travel_Rarely       1490
# 1056   28         2909.0       Yes  Travel_Frequently       1496
# 1124   39         8237.0        No      Travel_Rarely       1462
# 1163   37         3936.0        No      Travel_Rarely       1470
# 1202   38         3306.0        No      Travel_Rarely       1495
# 1236   36         6134.0       Yes      Travel_Rarely       1456
# 1342   34         9713.0        No      Travel_Rarely       1480
# 1369   28         9854.0       Yes      Travel_Rarely       1475
# 1422   35         2660.0        No      Travel_Rarely       1490
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 31    Research & Development                10          4             Other
# 52                     Sales                 1          5         Marketing
# 110   Research & Development                 1          4           Medical
# 117                    Sales                11          2  Technical Degree
# 155   Research & Development                 1          1  Technical Degree
# 164   Research & Development                 3          3           Medical
# 165   Research & Development                11          3     Life Sciences
# 172   Research & Development                 3          2           Medical
# 213   Research & Development                 8          4     Life Sciences
# 266   Research & Development                23          3           Medical
# 278   Research & Development                 1          3     Life Sciences
# 302   Research & Development                16          2           Medical
# 329   Research & Development                 5          5     Life Sciences
# 373   Research & Development                 1          2           Medical
# 396   Research & Development                 8          4             Other
# 408   Research & Development                 4          2     Life Sciences
# 412   Research & Development                18          3           Medical
# 416   Research & Development                 2          2     Life Sciences
# 427                    Sales                28          3         Marketing
# 441   Research & Development                 5          2             Other
# 469                    Sales                11          4             Other
# 471   Research & Development                10          3           Medical
# 665                    Sales                 2          4     Life Sciences
# 678   Research & Development                20          4           Medical
# 691   Research & Development                 9          4           Medical
# 706                    Sales                24          3     Life Sciences
# 766   Research & Development                 2          4           Medical
# 785   Research & Development                20          4  Technical Degree
# 819   Research & Development                 2          1     Life Sciences
# 842   Research & Development                12          1     Life Sciences
# 854   Research & Development                 7          3           Medical
# 869   Research & Development                15          2     Life Sciences
# 886   Research & Development                 1          3           Medical
# 944   Research & Development                 1          3     Life Sciences
# 986                    Sales                21          4     Life Sciences
# 992   Research & Development                25          2     Life Sciences
# 1001  Research & Development                11          3           Medical
# 1006  Research & Development                28          2     Life Sciences
# 1025                   Sales                 4          1           Medical
# 1044  Research & Development                 5          4  Technical Degree
# 1046  Research & Development                20          3     Life Sciences
# 1054  Research & Development                 7          4     Life Sciences
# 1056                   Sales                 1          3  Technical Degree
# 1124                   Sales                 6          3           Medical
# 1163  Research & Development                10          3           Medical
# 1202  Research & Development                 4          2           Medical
# 1236                   Sales                13          5         Marketing
# 1342                   Sales                 4          3     Life Sciences
# 1369                   Sales                13          2         Marketing
# 1422  Research & Development                11          4           Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 31                1  ...                         4             80
# 52                1  ...                         3             80
# 110               1  ...                         3             80
# 117               1  ...                         3             80
# 155               1  ...                         1             80
# 164               1  ...                         4             80
# 165               1  ...                         2             80
# 172               1  ...                         3             80
# 213               1  ...                         4             80
# 266               1  ...                         2             80
# 278               1  ...                         1             80
# 302               1  ...                         3             80
# 329               1  ...                         2             80
# 373               1  ...                         2             80
# 396               1  ...                         4             80
# 408               1  ...                         4             80
# 412               1  ...                         3             80
# 416               1  ...                         3             80
# 427               1  ...                         4             80
# 441               1  ...                         4             80
# 469               1  ...                         4             80
# 471               1  ...                         3             80
# 665               1  ...                         1             80
# 678               1  ...                         1             80
# 691               1  ...                         4             80
# 706               1  ...                         4             80
# 766               1  ...                         4             80
# 785               1  ...                         4             80
# 819               1  ...                         1             80
# 842               1  ...                         4             80
# 854               1  ...                         3             80
# 869               1  ...                         1             80
# 886               1  ...                         1             80
# 944               1  ...                         1             80
# 986               1  ...                         4             80
# 992               1  ...                         2             80
# 1001              1  ...                         1             80
# 1006              1  ...                         1             80
# 1025              1  ...                         3             80
# 1044              1  ...                         2             80
# 1046              1  ...                         3             80
# 1054              1  ...                         2             80
# 1056              1  ...                         4             80
# 1124              1  ...                         1             80
# 1163              1  ...                         1             80
# 1202              1  ...                         4             80
# 1236              1  ...                         2             80
# 1342              1  ...                         4             80
# 1369              1  ...                         4             80
# 1422              1  ...                         3             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 31                  0                  9                      5
# 52                  1                  9                      2
# 110                 0                 23                      1
# 117                 1                 10                      6
# 155                 1                 10                      1
# 164                 1                  1                      2
# 165                 0                 21                      5
# 172                 0                 13                      3
# 213                 2                 16                      5
# 266                 1                 10                      2
# 278                 1                  6                      6
# 302                 0                  9                      2
# 329                 1                 21                      2
# 373                 1                  5                      2
# 396                 0                  8                      3
# 408                 0                 31                      2
# 412                 1                 19                      5
# 416                 1                  1                      3
# 427                 0                 22                      5
# 441                 1                  8                      4
# 469                 0                  6                      2
# 471                 1                 18                      4
# 665                 0                  3                      3
# 678                 2                 13                      2
# 691                 1                  3                      2
# 706                 0                 22                      2
# 766                 1                 29                      2
# 785                 1                 14                      6
# 819                 0                  6                      2
# 842                 0                  1                      4
# 854                 1                  7                      2
# 869                 1                 25                      2
# 886                 1                 12                      2
# 944                 3                 10                      6
# 986                 2                  8                      2
# 992                 1                 13                      2
# 1001                0                  8                      6
# 1006                0                 20                      2
# 1025                2                  5                      3
# 1044                1                 20                      0
# 1046                0                  6                      3
# 1054                2                 29                      3
# 1056                1                  5                      3
# 1124                1                 11                      3
# 1163                1                  8                      2
# 1202                1                  7                      5
# 1236                3                 16                      3
# 1342                3                  9                      3
# 1369                0                  6                      0
# 1422                1                  5                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 31                  4              4                   2
# 52                  2              4                   3
# 110                 2             13                  12
# 117                 3              9                   7
# 155                 3             10                   7
# 164                 2              1                   1
# 165                 3              5                   4
# 172                 2              8                   7
# 213                 1             10                   9
# 266                 3              9                   0
# 278                 1              6                   5
# 302                 3              8                   3
# 329                 3              3                   2
# 373                 3              5                   2
# 396                 3              5                   2
# 408                 1              5                   2
# 412                 2             10                   7
# 416                 3              1                   0
# 427                 4             18                  13
# 441                 3              2                   2
# 469                 3              4                   2
# 471                 3              1                   0
# 665                 2              3                   2
# 678                 2              0                   0
# 691                 3              1                   1
# 706                 2              1                   0
# 766                 2              8                   1
# 785                 3             11                  10
# 819                 1              5                   3
# 842                 2              1                   1
# 854                 2              3                   2
# 869                 3              4                   2
# 886                 3             11                   9
# 944                 3              9                   8
# 986                 4              5                   4
# 992                 3              6                   4
# 1001                3              3                   2
# 1006                3              4                   3
# 1025                3              5                   4
# 1044                2              3                   2
# 1046                2              5                   2
# 1054                3              8                   7
# 1056                4              3                   2
# 1124                3              7                   6
# 1163                1              8                   4
# 1202                2              0                   0
# 1236                3              2                   2
# 1342                3              5                   3
# 1369                3              2                   0
# 1422                3              2                   2
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 31                         1                     3
# 52                         1                     3
# 110                       12                     8
# 117                        2                     8
# 155                        0                     9
# 164                        0                     1
# 165                        4                     4
# 172                        7                     2
# 213                        4                     7
# 266                        7                     8
# 278                        1                     4
# 302                        0                     7
# 329                        1                     1
# 373                        0                     4
# 396                        0                     2
# 408                        1                     4
# 412                        0                     8
# 416                        0                     0
# 427                       13                    11
# 441                        2                     0
# 469                        1                     2
# 471                        0                     0
# 665                        1                     2
# 678                        0                     0
# 691                        0                     0
# 706                        0                     0
# 766                        7                     7
# 785                       11                     1
# 819                        0                     4
# 842                        0                     0
# 854                        0                     2
# 869                        0                     3
# 886                        5                     7
# 944                        7                     5
# 986                        1                     4
# 992                        0                     5
# 1001                       0                     2
# 1006                       1                     3
# 1025                       0                     3
# 1044                       1                     2
# 1046                       1                     3
# 1054                       0                     7
# 1056                       1                     2
# 1124                       7                     6
# 1163                       7                     7
# 1202                       0                     0
# 1236                       2                     2
# 1342                       1                     0
# 1369                       2                     2
# 1422                       2                     2
#
# [50 rows x 35 columns]

# %%
high_rate_df['DailyRate'].sum()
# Out:
# 73749

# %% [markdown]
# # CODING TASK #6: PERFORM BASIC EDA ON BOTH CLASSES

# %%
hr_df

# %%
hr_df.info()

# %%
# It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other
# Let's drop 'EmployeeNumber' as well
hr_df.drop(['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber'], axis=1, inplace=True)

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1469 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
#  14  JobRole                   1469 non-null   object
#  15  JobSatisfaction           1470 non-null   int64
#  16  MaritalStatus             1469 non-null   object
#  17  MonthlyRate               1468 non-null   float64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   object
#  20  PercentSalaryHike         1469 non-null   float64
#  21  PerformanceRating         1469 non-null   float64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: float64(4), int64(19), object(8)
# memory usage: 356.1+ KB

# %%
# Let's see how many employees left the company!
left_df = hr_df[hr_df['Attrition'] == 'Yes']

# %%
# View employees who left
left_df

# %%
left_df.describe()

# %% [markdown]
# **PRACTICE OPPORTUNITY #6 [OPTIONAL]:**
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %% [markdown]
# # CODING TASK #7. PANDAS WITH FUNCTIONS

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df

# %%
# Let's assume the daily rate has increased by 10%
# Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)
def dailyrate_update(balance):
    return balance * 1.1 # assume that net worth increased by 10%

# %%
# You can apply a function to the DataFrame
hr_df['DailyRate'] = hr_df['DailyRate'].apply(dailyrate_update)
hr_df

# %% [markdown]
# **PRACTICE OPPORTUNITY #7 [OPTIONAL]:**
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %% [markdown]
# # CODING TASK #8: HISTOGRAM AND CORRELATION

# %%
hr_df.hist(bins = 30, figsize = (20,20), color = 'r');
# Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy

# %%
import matplotlib.pyplot as plt
import seaborn as sns
correlations = hr_df.corr()
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(correlations, annot = True)
# Job level is strongly correlated with total working hours
# Monthly income is strongly correlated with Job level
# Monthly income is strongly correlated with total working hours
# Age is strongly correlated with monthly income

# %% [markdown]
# **PRACTICE OPPORTUNITY #8 [OPTIONAL]:**
# - **Change the color of the heatmap [External Research is Required]**

# %%
import numpy as np
correlations = hr_df.corr()
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(correlations, cmap="YlGnBu", annot = True);

# %% [markdown]
# # FINAL CAPSTONE PROJECT OVERVIEW

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
